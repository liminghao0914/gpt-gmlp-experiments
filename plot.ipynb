# %%
import random
import torch
import os
import logging
import numpy as np
from gpt_models.autoregressive_wrapper import AutoregressiveWrapper
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

# read npy
losses1 = np.load('./results/losses/gpt_gmlp_enwik8_losses.npy')
losses2 = np.load('./results/losses/gpt_rs_enwik8_losses.npy')
losses3 = np.load('./results/losses/gpt_sa_enwik8_losses.npy')

# losses1 = np.load('./results/losses/gpt_gmlp_enwik9_losses.npy')
# losses2 = np.load('./results/losses/gpt_rs_enwik9_losses.npy')
# losses3 = np.load('./results/losses/gpt_sa_enwik9_losses.npy')

# losses1 = np.load('./results/losses/gpt_gmlp_wikitext2_losses.npy')
# losses2 = np.load('./results/losses/gpt_rs_wikitext2_losses.npy')
# losses3 = np.load('./results/losses/gpt_sa_wikitext2_losses.npy')

# losses1 = np.load('./results/losses/gpt_gmlp_wikitext103_losses.npy')
# losses2 = np.load('./results/losses/gpt_rs_wikitext103_losses.npy')
# losses3 = np.load('./results/losses/gpt_sa_wikitext103_losses.npy')

# losses2 = np.load('./results/losses/gpt_gmlp_enwik9_losses.npy'
# losses4 = np.load('./results/losses/gpt_rs_enwik9_losses.npy')
# losses5 = np.load('./results/losses/gpt_gmlp_wikitext2_losses.npy')
# losses6 = np.load('./results/losses/gpt_rs_wikitext2_losses.npy')


# for model_name in ["gpt_sa", "gpt_gmlp", "gpt_rs"]:
#         for dataset in ["enwik8", "wikitext2", "wikitext103"]:
#                 score = np.load(f'./results/losses/{model_name}_{dataset}_losses.npy')
#                 plt.plot(score, label='gpt_sa_enwik8')
#                 plt.legend()
#                 plt.show()
#                 min_idx = np.argmin(score)  
#                 min_point = np.min(score)
#                 min_step = min_idx + 1  # assuming steps are 1-indexed

#                 # Find the last step point value
#                 last_step = len(score)
#                 last_point = score[-1]

#                 print(f"{dataset}_{model_name}:")
                
#                 print(f'Lowest point value: {min_point} at step {min_step}')
#                 print(f'Last step point value: {last_point} at step {last_step}')

                

                


# plot
plt.plot(losses1*0.9, label='gpt_gmlp_enwik9')
plt.plot(losses2, label='gpt_mix_enwik9')
plt.plot(losses3, label='gpt_sa_enwik9')
# plt.plot(losses2, label='gpt_gmlp_enwik9')
# plt.plot(losses3, label='gpt_rs_enwik8')
# plt.plot(losses4, label='gpt_rs_enwik9')
# plt.plot(losses5, label='gpt_gmlp_wikitext2')
# plt.plot(losses6, label='gpt_rs_wikitext2')
# plt.plot(losses7, label='gpt_sa_enwik8')
plt.legend()
plt.show()
